# %% [markdown]
# # Explanatory Analysis
#
# in the following notebook, we will explore the datasets, manipulates some pictures and maybe build an image classifier NN

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageEnhance, ImageFilter
import json
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# ## 1. Dataset exploration

# %%
cardb_path="dataset-resized/cardboard/"
glass_path="dataset-resized/glass/"
metal_path="dataset-resized/metal/"
paper_path="dataset-resized/paper/"
plastic_path="dataset-resized/plastic/"
trash_path="dataset-resized/trash/"

# %%
cardb1=Image.open("dataset-resized/cardboard/cardboard1.jpg")
cardb1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>

# %%
glass1=Image.open(glass_path+'glass1.jpg')
glass1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>
